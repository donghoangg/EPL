# %% [markdown]
# đổi tên các cột

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_defensive_actions_stats_2018-2025.csv")
print(df.columns.tolist())
# Out:
# ['Squad', '# Pl', '90s', 'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl.1', 'Att', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr', 'Err', 'Season']

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_defensive_actions_stats_2018-2025.csv")

df = df.rename(columns={'Squad':'Club ID', '# Pl':'Num player', 'Tkl':'Num of tackle', 'Tackle in won poss':'Tackle when won poss','Def 3rd':'Tackle in def', 'Mid 3rd':'Tackle in mid', 'Att 3rd':'Tackle in att', 
                 'Tkl.1':'Dribblers tackled', 'Att':'Tackle challenges', 'Tkl%':'Per of dribblers tackled', 'Lost':'Tackle lost', 'Blocks':'Num blocks', 'Sh':'Shot block', 'Pass':'Pass block', 'Int':'Interceptions','Tkl+Int':'Tackle and Interception', 'Clr':'Clearances', 'Err':'Error','Season':'Season ID'})

df.to_csv(r"E:\project 1\data_18_25\squad\squad_defensive_actions_stats_2018-2025.csv",index=False)

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_defensive_actions_stats_2018-2025.csv")
df = df.rename(columns={'Club ID' : 'Squad'})

df.to_csv(r"E:\project 1\data_18_25\squad\squad_defensive_actions_stats_2018-2025.csv",index=False)

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_goalkeeping_stats_2018-2025.csv")
print(df.columns.tolist())
# Out:
# ['Squad', '# Pl', 'MP', 'Starts', 'Min', '90s', 'GA', 'GA90', 'SoTA', 'Saves', 'Save%', 'W', 'D', 'L', 'CS', 'CS%', 'PKatt', 'PKA', 'PKsv', 'PKm', 'Save%.1', 'Season']

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_goalkeeping_stats_2018-2025.csv")

# Rename columns
df.columns = [
    'Club ID',               # Squad
    'Num player',            # # Pl
    'Matches_Played',     # MP
    'Starts',             # Starts
    'Minutes',            # Min
    'Ninety_Minutes',     # 90s
    'Goals_Against',      # GA
    'GA_per_90',          # GA90
    'Shots_on_Target_Against', # SoTA
    'Saves',              # Saves
    'Save_Percentage',    # Save%
    'Wins',               # W
    'Draws',              # D
    'Losses',             # L
    'Clean_Sheets',       # CS
    'Clean_Sheet_Percentage', # CS%
    'PK_Attempted',       # PKatt
    'PK_Allowed',         # PKA
    'PK_Saved',           # PKsv
    'PK_Missed',          # PKm
    'PK_Save_Percentage', # Save%.1
    'Season'              # Season
]

df.to_csv(r"E:\project 1\data_18_25\squad\squad_goalkeeping_stats_2018-2025.csv",index=False)

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_gca_stats_2018-2025.csv")
print(df.columns.tolist())
# Out:
# ['Squad', '# Pl', '90s', 'SCA', 'SCA90', 'PassLive', 'PassDead', 'TO', 'Sh', 'Fld', 'Def', 'GCA', 'GCA90', 'PassLive.1', 'PassDead.1', 'TO.1', 'Sh.1', 'Fld.1', 'Def.1', 'Season']

# %%
import pandas as pd

# Read the file
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_gca_stats_2018-2025.csv")

# Rename all columns
df.columns = [
    'Club ID',                  # Squad
    'Num player',               # # Pl
    'Ninety_Minutes',        # 90s
    'SCA',                   # SCA - Shot-Creating Actions
    'SCA_per_90',            # SCA90
    'SCA_PassLive',          # PassLive
    'SCA_PassDead',          # PassDead
    'SCA_TO',                # TO (take-ons)
    'SCA_Shot',              # Sh
    'SCA_Fouled',            # Fld
    'SCA_Defense',           # Def
    'GCA',                   # GCA - Goal-Creating Actions
    'GCA_per_90',            # GCA90
    'GCA_PassLive',          # PassLive.1
    'GCA_PassDead',          # PassDead.1
    'GCA_TO',                # TO.1
    'GCA_Shot',              # Sh.1
    'GCA_Fouled',            # Fld.1
    'GCA_Defense',           # Def.1
    'Season'                 # Season
]

# Save back
df.to_csv(r"E:\project 1\data_18_25\squad\squad_gca_stats_2018-2025.csv", index=False)

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_pass_types_stats_2018-2025.csv")
print(df.columns.tolist())
# Out:
# ['Squad', '# Pl', '90s', 'Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp', 'Off', 'Blocks', 'Season']

# %%
import pandas as pd

# Read the file
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_pass_types_stats_2018-2025.csv")

# Rename all columns
df.columns = [
    'Club ID',               # Squad
    'Num player',            # # Pl
    'Ninety_Minutes',     # 90s
    'Pass_Attempts',      # Att - Total pass attempts
    'Pass_Live',          # Live - Live-ball passes
    'Pass_Dead',          # Dead - Dead-ball passes
    'Pass_FK',            # FK - Passes from free kicks
    'Pass_ThroughBall',   # TB - Through balls
    'Pass_Switch',        # Sw - Switches of play
    'Pass_Cross',         # Crs - Crosses
    'Pass_ThrowIn',       # TI - Throw-ins
    'Pass_CornerKick',    # CK - Corner kicks
    'Corner_InSwing',     # In - In-swinging corners
    'Corner_OutSwing',    # Out - Out-swinging corners
    'Corner_Straight',    # Str - Straight corners
    'Pass_Completed',     # Cmp - Passes completed
    'Pass_Offside',       # Off - Passes offside
    'Pass_Blocked',       # Blocks - Passes blocked
    'Season'              # Season
]

# Save the updated file
df.to_csv(r"E:\project 1\data_18_25\squad\squad_pass_types_stats_2018-2025.csv", index=False)

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_passing_stats_2018-2025.csv")
print(df.columns.tolist())
# Out:
# ['Squad', '# Pl', '90s', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist', 'Cmp.1', 'Att.1', 'Cmp%.1', 'Cmp.2', 'Att.2', 'Cmp%.2', 'Cmp.3', 'Att.3', 'Cmp%.3', 'Ast', 'xAG', 'xA', 'A-xAG', 'KP', 'pass to 1/3', 'PPA', 'CrsPA', 'PrgP', 'Season']

# %%
import pandas as pd

# Read the file
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_passing_stats_2018-2025.csv")

# Rename all columns
df.columns = [
    'Club ID',                    # Squad
    ' Num player',                 # # Pl
    'Ninety_Minutes',          # 90s
    'Pass_Completed_Total',    # Cmp
    'Pass_Attempted_Total',    # Att
    'Pass_Completion_Per_Total',  # Cmp%
    'Total_Distance',          # TotDist
    'Progressive_Distance',    # PrgDist
    'Pass_Completed_Short',    # Cmp.1
    'Pass_Attempted_Short',    # Att.1
    'Pass_Completion_Per_Short',  # Cmp%.1
    'Pass_Completed_Medium',   # Cmp.2
    'Pass_Attempted_Medium',   # Att.2
    'Pass_Completion_Per_Medium', # Cmp%.2
    'Pass_Completed_Long',     # Cmp.3
    'Pass_Attempted_Long',     # Att.3
    'Pass_Completion_Per_Long',   # Cmp%.3
    'Assists',                 # Ast
    'Expected_Assisted_Goals', # xAG
    'Expected_Assists',        # xA
    'Assist_minus_xAG',        # A-xAG
    'Key_Passes',              # KP
    'Pass_to_Final_Third',     # pass to 1/3
    'Passes_into_Penalty_Area',# PPA
    'Crosses_into_Penalty_Area',# CrsPA
    'Progressive_Passes',      # PrgP
    'Season'                   # Season
]

# Save the updated file
df.to_csv(r"E:\project 1\data_18_25\squad\squad_passing_stats_2018-2025.csv", index=False)

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_possession_stats_2018-2025.csv")
print(df.columns.tolist())
# Out:
# ['Squad', '# Pl', 'Poss', '90s', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Att Pen', 'Live', 'Att', 'Succ', 'Succ%', 'Tkld', 'Tkld%', 'Carries', 'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis', 'Rec', 'PrgR', 'Season']

# %%
import pandas as pd

# Đọc file
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_possession_stats_2018-2025.csv")

# Đổi tên cột
df = df.rename(columns={
    'Squad': 'Club ID',
    '# Pl': 'Num player',
    'Poss': 'Possession_Percentage',
    '90s': 'Ninety_Minutes',
    'Touches': 'Total_Touches',
    'Def Pen': 'Touches_Defensive_Penalty_Area',
    'Def 3rd': 'Touches_Defensive_Third',
    'Mid 3rd': 'Touches_Middle_Third',
    'Att 3rd': 'Touches_Attacking_Third',
    'Att Pen': 'Touches_Attacking_Penalty_Area',
    'Live': 'Live_Ball_Touches',
    'Att': 'Take_On_Attempts',
    'Succ': 'Take_Ons_Successful',
    'Succ%': 'Take_Ons_Success_Percentage',
    'Tkld': 'Tackled_During_Take_Ons',
    'Tkld%': 'Tackled_Percentage',
    'Carries': 'Total_Carries',
    'TotDist': 'Total_Carrying_Distance',
    'PrgDist': 'Progressive_Carrying_Distance',
    'PrgC': 'Progressive_Carries',
    '1/3': 'Carries_Into_Final_Third',
    'CPA': 'Carries_Into_Penalty_Area',
    'Mis': 'Miscontrols',
    'Dis': 'Dispossessed',
    'Rec': 'Passes_Received',
    'PrgR': 'Progressive_Passes_Received',
    'Season': 'Season'
})

# Ghi lại file
df.to_csv(r"E:\project 1\data_18_25\squad\squad_possession_stats_2018-2025.csv", index=False)

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_shooting_stats_2018-2025.csv")
print(df.columns.tolist())
# Out:
# ['Squad', '# Pl', '90s', 'Gls', 'Sh', 'SoT', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'Dist', 'FK', 'PK', 'PKatt', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG', 'Season']

# %%
import pandas as pd

# Đọc file
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_shooting_stats_2018-2025.csv")

# Đổi tên cột
df = df.rename(columns={
    'Squad': 'Club ID',
    '# Pl': 'Num player',
    '90s': 'Ninety_Minutes',
    'Gls': 'Goals',
    'Sh': 'Shots',
    'SoT': 'Shots_On_Target',
    'SoT%': 'Shots_On_Target_Percentage',
    'Sh/90': 'Shots_Per_90',
    'SoT/90': 'Shots_On_Target_Per_90',
    'G/Sh': 'Goals_Per_Shot',
    'G/SoT': 'Goals_Per_Shot_On_Target',
    'Dist': 'Average_Shot_Distance',
    'FK': 'Free_Kick_Shots',
    'PK': 'Penalty_Kicks_Made',
    'PKatt': 'Penalty_Kicks_Attempted',
    'xG': 'Expected_Goals',
    'npxG': 'Non_Penalty_Expected_Goals',
    'npxG/Sh': 'Non_Penalty_xG_Per_Shot',
    'G-xG': 'Goals_Minus_Expected_Goals',
    'np:G-xG': 'Non_Penalty_Goals_Minus_xG',
    'Season': 'Season'
})

# Ghi lại file
df.to_csv(r"E:\project 1\data_18_25\squad\squad_shooting_stats_2018-2025.csv", index=False)

# %%
import pandas as pd 
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_standard_stats_2018-2025.csv")
print(df.columns.tolist())
# Out:
# ['Season', 'Squad', '# Pl', 'Age', 'Poss', 'MP', 'Starts', 'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgC', 'PrgP', 'Gls.1', 'Ast.1', 'G+A.1', 'G-PK.1', 'G+A-PK', 'xG.1', 'xAG.1', 'xG+xAG', 'npxG.1', 'npxG+xAG.1']

# %%
import pandas as pd

# Đọc file
df = pd.read_csv(r"E:\project 1\data_18_25\squad\squad_standard_stats_2018-2025.csv")

# Đổi tên cột
df = df.rename(columns={
    'Season': 'Season',
    'Squad': 'Club ID',
    '# Pl': 'Num player',
    'Age': 'Average_Age',
    'Poss': 'Possession_Percentage',
    'MP': 'Matches_Played',
    'Starts': 'Matches_Started',
    'Min': 'Minutes_Played',
    '90s': 'Ninety_Minutes',
    'Gls': 'Goals',
    'Ast': 'Assists',
    'G+A': 'Goals_And_Assists',
    'G-PK': 'Non_Penalty_Goals',
    'PK': 'Penalty_Kicks_Made',
    'PKatt': 'Penalty_Kicks_Attempted',
    'CrdY': 'Yellow_Cards',
    'CrdR': 'Red_Cards',
    'xG': 'Expected_Goals',
    'npxG': 'Non_Penalty_Expected_Goals',
    'xAG': 'Expected_Assisted_Goals',
    'npxG+xAG': 'Non_Penalty_xG_Plus_xAG',
    'PrgC': 'Progressive_Carries',
    'PrgP': 'Progressive_Passes',

    # Các cột phần trăm hoặc theo 90 phút
    'Gls.1': 'Goals_Per_90',
    'Ast.1': 'Assists_Per_90',
    'G+A.1': 'Goals_And_Assists_Per_90',
    'G-PK.1': 'Non_Penalty_Goals_Per_90',
    'G+A-PK': 'Goals_And_Assists_Non_Penalty_Per_90',
    'xG.1': 'Expected_Goals_Per_90',
    'xAG.1': 'Expected_Assisted_Goals_Per_90',
    'xG+xAG': 'Expected_Goals_And_Assists_Per_90',
    'npxG.1': 'Non_Penalty_Expected_Goals_Per_90',
    'npxG+xAG.1': 'Non_Penalty_xG_Plus_xAG_Per_90'
})

# Ghi lại file
df.to_csv(r"E:\project 1\data_18_25\squad\squad_standard_stats_2018-2025.csv", index=False)
